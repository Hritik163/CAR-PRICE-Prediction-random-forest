# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
m=df['Car_Name']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
df['Fuel_Type']=df['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':2})

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df['Seller_Type']=df['Seller_Type'].map({'Individual':0,'Dealer':1})

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
df['Transmission']=df['Transmission'].map({'Manual':0,'Automatic':1})

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encod=LabelEncoder()
df['Car_Name']=encod.fit_transform(df['Car_Name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    int64
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    int64
#  6   Seller_Type    301 non-null    int64
#  7   Transmission   301 non-null    int64
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 21.3 KB

# %%
df.describe()
# Out:
#          Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count  301.000000   301.000000     301.000000     301.000000     301.000000
# mean    62.571429  2013.627907       4.661296       7.628472   36947.205980
# std     25.573535     2.891554       5.082812       8.644115   38886.883882
# min      0.000000  2003.000000       0.100000       0.320000     500.000000
# 25%     47.000000  2012.000000       0.900000       1.200000   15000.000000
# 50%     69.000000  2014.000000       3.600000       6.400000   32000.000000
# 75%     82.000000  2016.000000       6.000000       9.900000   48767.000000
# max     97.000000  2018.000000      35.000000      92.600000  500000.000000
#
#         Fuel_Type  Seller_Type  Transmission       Owner
# count  301.000000   301.000000    301.000000  301.000000
# mean     0.212625     0.647841      0.132890    0.043189
# std      0.425801     0.478439      0.340021    0.247915
# ...

# %%
df.corr()
# Out:
#                Car_Name      Year  Selling_Price  Present_Price  Kms_Driven  \
# Car_Name       1.000000  0.017265       0.499198       0.475539    0.064453
# Year           0.017265  1.000000       0.236141      -0.047584   -0.524342
# Selling_Price  0.499198  0.236141       1.000000       0.878983    0.029187
# Present_Price  0.475539 -0.047584       0.878983       1.000000    0.203647
# Kms_Driven     0.064453 -0.524342       0.029187       0.203647    1.000000
# Fuel_Type      0.371446  0.053643       0.509467       0.440415    0.166801
# Seller_Type    0.829718  0.039896       0.550724       0.512030    0.101419
# Transmission   0.059855 -0.000394       0.367128       0.348715    0.162510
# Owner         -0.081192 -0.182104      -0.088344       0.008057    0.089216
#
#                Fuel_Type  Seller_Type  Transmission     Owner
# Car_Name        0.371446     0.829718      0.059855 -0.081192
# Year            0.053643     0.039896     -0.000394 -0.182104
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0          90  2014           3.35           5.59       27000          0
# 1          93  2013           4.75           9.54       43000          1
# 2          68  2017           7.25           9.85        6900          0
# 3          96  2011           2.85           4.15        5200          0
# 4          92  2014           4.60           6.87       42450          1
# ..        ...   ...            ...            ...         ...        ...
# 296        69  2016           9.50          11.60       33988          1
# 297        66  2015           4.00           5.90       60000          0
# 298        69  2009           3.35          11.00       87934          0
# 299        69  2017          11.50          12.50        9000          1
# 300        66  2016           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner
# 0              1             0      0
# ...

# %% [markdown]
# split the target feature

# %%
x=df[['Car_Name','Year','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
y=df['Selling_Price']

# %%
x
# Out:
#      Car_Name  Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0          90  2014           5.59       27000          0            1
# 1          93  2013           9.54       43000          1            1
# 2          68  2017           9.85        6900          0            1
# 3          96  2011           4.15        5200          0            1
# 4          92  2014           6.87       42450          1            1
# ..        ...   ...            ...         ...        ...          ...
# 296        69  2016          11.60       33988          1            1
# 297        66  2015           5.90       60000          0            1
# 298        69  2009          11.00       87934          0            1
# 299        69  2017          12.50        9000          1            1
# 300        66  2016           5.90        5464          0            1
#
#      Transmission  Owner
# 0               0      0
# 1               0      0
# 2               0      0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((201, 8), (100, 8), (201,), (100,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model=LinearRegression()

# %%
linear_model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear_model.predict(X_test_scaled)

# %% [markdown]
# calculate the accuracy

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.858
# RMSE: 1.95
# MAE: 1.26

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()

# %%
lasso.fit(X_train_scaled,y_train)
# Out:
# Lasso()

# %%
y_pred=lasso.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.722
# RMSE: 2.73
# MAE: 1.94

# %%
from sklearn.linear_model import Ridge

# %%
ridge=Ridge()

# %%
ridge.fit(X_train_scaled,y_train)
# Out:
# Ridge()

# %%
y_pred=ridge.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.858
# RMSE: 1.95
# MAE: 1.27

# %%
from sklearn.linear_model import ElasticNet

# %%
ele=ElasticNet()

# %%
ele.fit(X_train_scaled,y_train)
# Out:
# ElasticNet()

# %%
y_pred=ele.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.713
# RMSE: 2.77
# MAE: 1.79

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree=DecisionTreeRegressor()

# %%
tree.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=tree.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.961
# RMSE: 1.02
# MAE: 0.67

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random=RandomForestRegressor()

# %%
random.fit(X_train_scaled,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=random.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_test: true prices
# y_pred: predicted prices by your model

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f'R²: {r2:.3f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
# Out:
# R²: 0.952
# RMSE: 1.13
# MAE: 0.65

# %%
import pickle

# %%
pickle.dump(random,open('model.pkl','wb'))

# %%
pickle.dump(scaler,open('scaler.pkl','wb'))
